# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\KPMG sem3\fraud detection\raud-detection-lr.csv')

# %%
df.head(10)
# Out:
#    transaction_id   age     income  transaction_amount  account_age_days  \
# 0               1  23.0   30051.86               70.81              1400
# 1               2  62.0   40837.89              170.51               895
# 2               3  55.0   63875.37              123.26              2136
# 3               4  43.0   38929.69              408.65                58
# 4               5  42.0   47192.34              420.26              2981
# 5               6  66.0   70111.05               28.72              2727
# 6               7  22.0   45399.82              511.87              3090
# 7               8  57.0   62281.60               97.73              3270
# 8               9  29.0  132070.23              227.98              3553
# 9              10  23.0   50039.41               70.39               617
#
#    transactions_24h  failed_attempts_24h  merchant_risk_score  \
# 0                 5                    2               0.1424
# ...

# %%
print("columns and rows of dataset")

print(df.shape)
print("all columns list:  ")
for col in df.columns:
    print(col)
# Out:
# columns and rows of dataset
# (10000, 16)
# all columns list
# transaction_id
# age
# income
# transaction_amount
# account_age_days
# transactions_24h
# failed_attempts_24h
# merchant_risk_score
# distance_from_home_km
# device_trust_score
# is_international
# is_new_device
# transaction_hour
# merchant_category
# payment_method
# is_fraud

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   transaction_id         10000 non-null  int64
#  1   age                    9649 non-null   float64
#  2   income                 9547 non-null   float64
#  3   transaction_amount     10000 non-null  float64
#  4   account_age_days       10000 non-null  int64
#  5   transactions_24h       10000 non-null  int64
#  6   failed_attempts_24h    10000 non-null  int64
#  7   merchant_risk_score    10000 non-null  float64
#  8   distance_from_home_km  10000 non-null  float64
#  9   device_trust_score     9802 non-null   float64
#  10  is_international       10000 non-null  int64
#  11  is_new_device          10000 non-null  int64
#  12  transaction_hour       10000 non-null  int64
#  13  merchant_category      9747 non-null   object
# ...

# %%
df.describe()
# Out:
#        transaction_id          age         income  transaction_amount  \
# count    10000.000000  9649.000000    9547.000000        10000.000000
# mean      5010.670600    45.832832   63861.855113          305.908919
# std       2886.602298    16.376761   37540.265032          374.543309
# min          1.000000    18.000000   15000.000000            5.000000
# 25%       2521.750000    32.000000   38072.190000           94.655000
# 50%       5023.500000    46.000000   54237.070000          185.700000
# 75%       7513.250000    60.000000   79356.720000          365.187500
# max      10000.000000    74.000000  250000.000000         5000.000000
#
#        account_age_days  transactions_24h  failed_attempts_24h  \
# count      10000.000000      10000.000000           10000.0000
# mean        2020.186800          4.033300               0.3408
# std         1139.043984          2.024747               0.5830
# min           30.000000          0.000000               0.0000
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id             0
# age                      351
# income                   453
# transaction_amount         0
# account_age_days           0
# transactions_24h           0
# failed_attempts_24h        0
# merchant_risk_score        0
# distance_from_home_km      0
# device_trust_score       198
# is_international           0
# is_new_device              0
# transaction_hour           0
# merchant_category        253
# payment_method           199
# is_fraud                   0
# dtype: int64

# %%
df['age']= df['age'].fillna(df['age'].median())
df['income']= df['income'].fillna(df['income'].median())
df['device_trust_score']=df['device_trust_score'].fillna(df['device_trust_score'].median())
df['merchant_category'] = df['merchant_category'].fillna(df['merchant_category'].mode()[0])
df['payment_method'] = df['payment_method'].fillna(df['payment_method'].mode()[0])

# %%
df.duplicated().sum()
# Out:
# np.int64(197)

# %%
df= df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# transaction_id           0
# age                      0
# income                   0
# transaction_amount       0
# account_age_days         0
# transactions_24h         0
# failed_attempts_24h      0
# merchant_risk_score      0
# distance_from_home_km    0
# device_trust_score       0
# is_international         0
# is_new_device            0
# transaction_hour         0
# merchant_category        0
# payment_method           0
# is_fraud                 0
# dtype: int64
